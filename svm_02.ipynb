# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df=pd.read_csv("C:\\Users\\user\\Downloads\\archive (1)\\UCI_Credit_Card.csv")
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
x=df.drop(['default.payment.next.month'],axis=1)
x
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %% [raw]
# y=df['default.payment.next.month']
# y

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.25,random_state=24)

# %%
x_train
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 28619  28620    50000.0    2          3         1   48      0      0      0
# 11748  11749   100000.0    2          1         1   34      1      2      2
# 145      146    50000.0    1          1         2   28      0      0      0
# 12427  12428   200000.0    2          2         2   35     -1     -1     -1
# 19656  19657   100000.0    2          1         2   33     -1      2      2
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 19857  19858   340000.0    2          1         2   38      0      0      0
# 24919  24920   150000.0    1          1         2   41     -1      2     -1
# 14528  14529   180000.0    2          3         2   25      0      0      0
# 899      900   200000.0    1          1         1   36     -1     -1      0
# 12706  12707   390000.0    1          1         1   38     -1     -1     -1
#
# ...

# %%
x_test
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 25706  25707   360000.0    2          1         1   39     -1     -1     -1
# 2412    2413    30000.0    1          2         3   50      2      0      0
# 13346  13347   210000.0    2          1         1   23     -2     -2     -2
# 23685  23686    60000.0    2          3         1   63      0      0      0
# 9943    9944   160000.0    2          2         1   33      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 9589    9590   170000.0    2          1         2   30      1     -2     -1
# 14834  14835   200000.0    1          1         2   37      0      0      0
# 23716  23717    30000.0    2          3         1   52      1     -2     -2
# 5941    5942    30000.0    2          2         1   30      0      0      0
# 14314  14315    80000.0    1          2         1   60      2      2      2
#
# ...

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.7775111111111112

# %%
from sklearn.linear_model import LogisticRegression
model_01=LogisticRegression()
model_01.fit(x_train,y_train)
model_01.score(x_test,y_test)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7773777777777777

# %%
from sklearn.ensemble import RandomForestClassifier
model_02=RandomForestClassifier()
model_02.fit(x_train,y_train)
model_02.score(x_test,y_test)
# Out:
# 0.8147111111111112
