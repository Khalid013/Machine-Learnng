# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:\\Users\\user\\Downloads\\archive (3)\\dataset_2191_sleep.csv",na_values=["?"])
df
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0      6654.000        5712.0           38.6           645.0                3
# 1         1.000           6.6            4.5            42.0                3
# 2         3.385          44.5           14.0            60.0                1
# 3         0.920           5.7            NaN            25.0                5
# 4      2547.000        4603.0           69.0           624.0                3
# ..          ...           ...            ...             ...              ...
# 57        2.000          12.3            7.5           200.0                3
# 58        0.104           2.5            2.3            46.0                3
# 59        4.190          58.0           24.0           210.0                4
# 60        3.500           3.9            3.0            14.0                2
# 61        4.050          17.0           13.0            38.0                3
#
# ...

# %%
df.head()
# Out:
#    body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0     6654.000        5712.0           38.6           645.0                3
# 1        1.000           6.6            4.5            42.0                3
# 2        3.385          44.5           14.0            60.0                1
# 3        0.920           5.7            NaN            25.0                5
# 4     2547.000        4603.0           69.0           624.0                3
#
#    sleep_exposure_index  danger_index  total_sleep
# 0                     5             3          3.3
# 1                     1             3          8.3
# 2                     1             1         12.5
# 3                     2             3         16.5
# 4                     5             4          3.9

# %%
df.info
# Out:
# <bound method DataFrame.info of     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0      6654.000        5712.0           38.6           645.0                3
# 1         1.000           6.6            4.5            42.0                3
# 2         3.385          44.5           14.0            60.0                1
# 3         0.920           5.7            NaN            25.0                5
# 4      2547.000        4603.0           69.0           624.0                3
# ..          ...           ...            ...             ...              ...
# 57        2.000          12.3            7.5           200.0                3
# 58        0.104           2.5            2.3            46.0                3
# 59        4.190          58.0           24.0           210.0                4
# 60        3.500           3.9            3.0            14.0                2
# 61        4.050          17.0           13.0            38.0                3
#
# ...

# %%
df.isnull()
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0         False         False          False           False            False
# 1         False         False          False           False            False
# 2         False         False          False           False            False
# 3         False         False           True           False            False
# 4         False         False          False           False            False
# ..          ...           ...            ...             ...              ...
# 57        False         False          False           False            False
# 58        False         False          False           False            False
# 59        False         False          False           False            False
# 60        False         False          False           False            False
# 61        False         False          False           False            False
#
# ...

# %%
df.isnull().sum()
# Out:
# body_weight             0
# brain_weight            0
# max_life_span           4
# gestation_time          4
# predation_index         0
# sleep_exposure_index    0
# danger_index            0
# total_sleep             4
# dtype: int64

# %%
a=df['max_life_span'].mean()
b=df['gestation_time'].mean()
c=df['total_sleep'].mean()
print(f"a={a} , b={b} and c={c}")
# Out:
# a=19.877586206896552 , b=142.35344827586206 and c=10.532758620689652

# %%
df['max_life_span']=df['max_life_span'].fillna(a)
df['gestation_time']=df['gestation_time'].fillna(b)
df['total_sleep']=df['total_sleep'].fillna(c)

# %%
df
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0      6654.000        5712.0      38.600000           645.0                3
# 1         1.000           6.6       4.500000            42.0                3
# 2         3.385          44.5      14.000000            60.0                1
# 3         0.920           5.7      19.877586            25.0                5
# 4      2547.000        4603.0      69.000000           624.0                3
# ..          ...           ...            ...             ...              ...
# 57        2.000          12.3       7.500000           200.0                3
# 58        0.104           2.5       2.300000            46.0                3
# 59        4.190          58.0      24.000000           210.0                4
# 60        3.500           3.9       3.000000            14.0                2
# 61        4.050          17.0      13.000000            38.0                3
#
# ...

# %%
df.isnull().sum()
# Out:
# body_weight             0
# brain_weight            0
# max_life_span           0
# gestation_time          0
# predation_index         0
# sleep_exposure_index    0
# danger_index            0
# total_sleep             0
# dtype: int64

# %%
x=df.drop('total_sleep',axis=1)
x
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 0      6654.000        5712.0      38.600000           645.0                3
# 1         1.000           6.6       4.500000            42.0                3
# 2         3.385          44.5      14.000000            60.0                1
# 3         0.920           5.7      19.877586            25.0                5
# 4      2547.000        4603.0      69.000000           624.0                3
# ..          ...           ...            ...             ...              ...
# 57        2.000          12.3       7.500000           200.0                3
# 58        0.104           2.5       2.300000            46.0                3
# 59        4.190          58.0      24.000000           210.0                4
# 60        3.500           3.9       3.000000            14.0                2
# 61        4.050          17.0      13.000000            38.0                3
#
# ...

# %%
y=df['total_sleep']
y
# Out:
# 0      3.300000
# 1      8.300000
# 2     12.500000
# 3     16.500000
# 4      3.900000
#         ...
# 57     5.400000
# 58    15.800000
# 59    10.300000
# 60    19.400000
# 61    10.532759
# Name: total_sleep, Length: 62, dtype: float64

# %%
import seaborn as sns
sns.scatterplot(data=df,x='x',y='y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 2
#       1 import seaborn as sns
# ----> 2 sns.scatterplot(data=df,x='x',y='y')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
x_train
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 13      187.100        419.00      40.000000      365.000000                5
# 33       62.000       1320.00     100.000000      267.000000                1
# 34        0.122          3.00      19.877586       30.000000                2
# 3         0.920          5.70      19.877586       25.000000                5
# 17        0.200          5.00      10.400000      120.000000                2
# 54        1.400         12.50      12.700000       90.000000                2
# 8         3.300         25.60      28.000000       63.000000                1
# 6         0.023          0.30      19.000000       35.000000                1
# 31        0.005          0.14       2.600000       21.500000                5
# 4      2547.000       4603.00      69.000000      624.000000                3
# 45        2.500         12.10      18.000000       31.000000                5
# ...

# %%
x_test
# Out:
#     body_weight  brain_weight  max_life_span  gestation_time  predation_index  \
# 50        0.750          12.3       7.000000      225.000000                2
# 56        0.900           2.6       4.500000       60.000000                2
# 0      6654.000        5712.0      38.600000      645.000000                3
# 57        2.000          12.3       7.500000      200.000000                3
# 5        10.550         179.5      27.000000      180.000000                4
# 48        4.235          50.4       9.800000       52.000000                1
# 16        0.785           3.5       6.000000       42.000000                2
# 12        0.550           2.4      19.877586      142.353448                2
# 25       36.330         119.5      16.200000       63.000000                1
# 59        4.190          58.0      24.000000      210.000000                4
# 30       35.000          56.0      16.300000       33.000000                3
# ...

# %%
y_train
# Out:
# 13     3.100000
# 33     8.000000
# 34    10.600000
# 3     16.500000
# 17    10.700000
# 54    11.000000
# 8     14.500000
# 6     19.700000
# 31     9.100000
# 4      3.900000
# 45     8.400000
# 19    18.100000
# 52     2.600000
# 36    13.200000
# 53     3.800000
# 41    17.000000
# 58    15.800000
# 15     8.600000
# 40    10.532759
# 27     8.200000
# 26    13.800000
# 24     6.200000
# 44     8.400000
# 11     3.900000
# 32    19.900000
# 55    10.300000
# 43    13.700000
# 37    12.800000
# 29    10.800000
# 46    12.500000
# 1      8.300000
# 21     3.800000
# 2     12.500000
# 49     9.600000
# 39    17.400000
# 35    11.200000
# 23    12.000000
# 60    19.400000
# 10    12.500000
# 22    14.400000
# 18     6.100000
# 61    10.532759
# 20    10.532759
# 7      6.200000
# 42    10.900000
# 14     8.400000
# 28     2.900000
# 51     5.400000
# 38    19.400000
# Name: total_sleep, dtype: float64

# %%
y_test
# Out:
# 50     6.600000
# 56    13.300000
# 0      3.300000
# 57     5.400000
# 5      9.800000
# 48     9.800000
# 16    10.700000
# 12    10.300000
# 25    13.000000
# 59    10.300000
# 30    10.532759
# 9      9.700000
# 47    13.200000
# Name: total_sleep, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[7.34571524e-02, 9.09999435e-02, 3.87755102e-01, 5.76797386e-01,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [2.43404483e-02, 2.86747805e-01, 1.00000000e+00, 4.16666667e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.59364859e-05, 6.21352811e-04, 1.82424349e-01, 2.94117647e-02,
#         2.50000000e-01, 0.00000000e+00, 0.00000000e+00],
#        [3.59246877e-04, 1.20794463e-03, 1.82424349e-01, 2.12418301e-02,
#         1.00000000e+00, 2.50000000e-01, 5.00000000e-01],
#        [7.65608099e-05, 1.05586527e-03, 8.57142857e-02, 1.76470588e-01,
#         2.50000000e-01, 2.50000000e-01, 2.50000000e-01],
#        [5.47704255e-04, 2.68528697e-03, 1.09183673e-01, 1.27450980e-01,
#         2.50000000e-01, 2.50000000e-01, 2.50000000e-01],
#        [1.29368138e-03, 5.53134356e-03, 2.65306122e-01, 8.33333333e-02,
#         0.00000000e+00, 2.50000000e-01, 0.00000000e+00],
# ...

# %%
x_test_scaled
# Out:
# array([[2.92501556e-04, 2.64183573e-03, 5.10204082e-02, 3.48039216e-01,
#         2.50000000e-01, 2.50000000e-01, 2.50000000e-01],
#        [3.51394486e-04, 5.34450320e-04, 2.55102041e-02, 7.84313725e-02,
#         2.50000000e-01, 0.00000000e+00, 2.50000000e-01],
#        [2.61248844e+00, 1.24093716e+00, 3.73469388e-01, 1.03431373e+00,
#         5.00000000e-01, 1.00000000e+00, 5.00000000e-01],
#        [7.83275978e-04, 2.64183573e-03, 5.61224490e-02, 3.07189542e-01,
#         5.00000000e-01, 0.00000000e+00, 5.00000000e-01],
#        [4.14017303e-03, 3.89670770e-02, 2.55102041e-01, 2.74509804e-01,
#         7.50000000e-01, 7.50000000e-01, 7.50000000e-01],
#        [1.66078065e-03, 1.09192980e-02, 7.95918367e-02, 6.53594771e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.06243240e-04, 7.29980925e-04, 4.08163265e-02, 4.90196078e-02,
#         2.50000000e-01, 2.50000000e-01, 2.50000000e-01],
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeRegressor()

# %%
scor=model.predict(x_test_scaled)

# %%
scor
# Out:
# array([ 5.4,  8.4,  3.9,  5.4, 10.9, 12.5, 15.8, 18.1, 12.5,  5.4,  8.4,
#         5.4, 13.2])

# %%
value=model.score(x_test_scaled,y_test)
value
# Out:
# -0.5657270048517629
