# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df=pd.read_csv("C:\\Users\\user\\Downloads\\archive (2)\\framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
edu=df['education'].mode()[0]
edu
# Out:
# np.float64(1.0)

# %%
df['education']=df['education'].fillna(edu)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
cig=df['cigsPerDay'].mean()
cig
# Out:
# np.float64(9.003088619624615)

# %%
BPM=df['BPMeds'].median()
BPM
# Out:
# np.float64(0.0)

# %%
Chol=df['totChol'].median()
Chol
# Out:
# np.float64(234.0)

# %%
BM=df['BMI'].median()
BM
# Out:
# np.float64(25.4)

# %%
Heart=df['heartRate'].median()
Heart
# Out:
# np.float64(75.0)

# %%
Gloco=df['glucose'].median()
Gloco
# Out:
# np.float64(78.0)

# %%
df['cigsPerDay']=df['cigsPerDay'].fillna(cig)
df['BPMeds']=df['BPMeds'].fillna(BPM)
df['totChol']=df['totChol'].fillna(Chol)
df['BMI']=df['BMI'].fillna(BM)
df['heartRate']=df['heartRate'].fillna(Heart)
df['glucose']=df['glucose'].fillna(Gloco)

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
x=df.drop(['TenYearCHD'],axis=1)
x
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
y=df['TenYearCHD']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4233    1
# 4234    0
# 4235    0
# 4236    0
# 4237    0
# Name: TenYearCHD, Length: 4238, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)
x_train
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1162     1   61        1.0              0         0.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# 2968     1   46        1.0              1        43.0     0.0
# 3594     0   45        1.0              1         5.0     0.0
# 535      1   43        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 2895     0   45        2.0              1        30.0     0.0
# 2763     1   46        1.0              1         9.0     0.0
# 905      1   38        2.0              1        20.0     0.0
# 3980     0   55        2.0              0         0.0     0.0
# 235      0   36        1.0              1         3.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1162                0             0         0    214.0  100.0   65.0  30.18
# ...

# %%
y_train
# Out:
# 1162    0
# 4       0
# 2968    0
# 3594    0
# 535     0
#        ..
# 2895    0
# 2763    0
# 905     0
# 3980    0
# 235     0
# Name: TenYearCHD, Length: 3178, dtype: int64

# %%
x_test
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 906      1   53        1.0              0         0.0     0.0
# 857      0   44        1.0              0         0.0     0.0
# 2761     0   44        4.0              0         0.0     0.0
# 108      0   66        1.0              0         0.0     0.0
# 2894     0   38        1.0              1         9.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 689      1   64        1.0              1        18.0     0.0
# 60       1   56        4.0              1        20.0     0.0
# 3898     1   68        1.0              0         0.0     0.0
# 3339     0   61        2.0              0         0.0     1.0
# 1685     0   53        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 906                 0             0         0    220.0  127.0   76.0  24.27
# ...

# %%
y_train
# Out:
# 1162    0
# 4       0
# 2968    0
# 3594    0
# 535     0
#        ..
# 2895    0
# 2763    0
# 905     0
# 3980    0
# 235     0
# Name: TenYearCHD, Length: 3178, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(1060,))

# %%
model.score(x_test,y_test)
# Out:
# 0.8641509433962264
